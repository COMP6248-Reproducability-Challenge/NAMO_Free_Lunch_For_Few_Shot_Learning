# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
Ns = np.arange(0, 2.5, step=0.5)
with_accuracy = [0.200000, 0.691600, 0.645867, 0.565600, 0.488667]
without_accuracy = [0.200000, 0.648267, 0.588800, 0.543200, 0.490267]

fig, ax = plt.subplots(nrows=1,ncols=1,figsize=(10,5))
ax.plot(Ns, with_accuracy, label='training with generated features')
ax.plot(Ns, without_accuracy, label='training without generated features')

ax.set_title("miniImageNet")
ax.set_xlabel("Values of lambda")
ax.set_ylabel("Test Accuracy(5way-1shot)")
ax.set_xlim(0,2)
# ax.set_ylim(0,2000)
ax.legend()
ax.grid()
plt.savefig("Reproduction_of_Figure_3_Left.png")

# %%
# Finished With Without
# 0  0.648267   0.588800
# 10  0.666533   0.591333
# 50  0.681467  0.598667
# 100  0.688000 0.625600
# 150  0.686800   0.631333

# 200 0.685200  0.634933
# 250 0.688267  0.638800
# 300 0.685333  0.643867
# 350 0.692000  0.645867

# 400 0.691333  0.641867
# 450 0.690933  0.640000
# 500 0.688133 0.640000
# 550 0.688400 0.642933

# 600 0.691733  0.642533
# 650 0.689467  0.646000
# 700 0.691467  0.647200
# 750 0.691467  0.645867
# Out:
# array([ 50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650,
#        700, 750])

# %%
Ns = [0, 10, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700, 750]
with_accuracy = [0.648267, 0.666533, 0.681467, 0.688000, 0.686800, 0.685200, 0.688267, 0.685333, 0.692000,
                 0.691333, 0.690933, 0.688133, 0.688400, 0.691733, 0.689467, 0.691467, 0.691467]

without_accuracy = [0.588800, 0.591333, 0.598667, 0.625600, 0.631333, 0.634933, 0.638800, 
                    0.643867, 0.645867, 0.641867, 0.640000, 0.640000, 0.642933, 0.642533, 0.646000, 0.647200, 0.645867]

fig, ax = plt.subplots(nrows=1,ncols=1,figsize=(10,5))
ax.plot(Ns, with_accuracy,  label='with Tukey Transformation')
ax.plot(Ns, without_accuracy, label='without Tukey Transformation')

ax.set_title("miniImageNet")
ax.set_xlabel("Number of Generated Features")
ax.set_ylabel("Test Accuracy(5way-1shot)")
ax.set_xlim(0,800)
# ax.set_ylim(0,2000)
ax.legend()
ax.grid()
plt.savefig("Reproduction_of_Figure_3_Right.png")
